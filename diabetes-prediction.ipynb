# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import joblib
import warnings
warnings.filterwarnings("ignore")

sns.set_style("whitegrid")

# %%
diabetes_dataset = pd.read_csv('diabetes.csv')
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1,2,1)
outcome_counts = diabetes_dataset['Outcome'].value_counts()
plt.bar(['Non-Diabetic', 'Diabetic'], outcome_counts.values, color=['#0f97e6', '#fa2912'])
plt.title(' Répartition des résultats du diabète', fontsize=14, fontweight='bold')
plt.ylabel('nombre de cas')

plt.subplot(1,2,2)
plt.pie(outcome_counts.values, labels=['Non diabétique', 'diabétique'],
        autopct='%1.1f%%', colors=["#0f97e6", "#fa2912"], startangle=90)
plt.title('Distribution en pourcentage', fontsize=14, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(10,8))


correlation = diabetes_dataset.corr()


sns.heatmap(
    correlation,
    annot=True,
    cmap="YlGnBu",   
    square=True,
    linewidths=0.5,
    fmt=".2f"
)


plt.title(
    "Carte de Corrélation des Variables du Diabète",
    fontsize=20,
    pad=20,
    fontweight="bold",
    color="#1f4e79"
)

plt.show()

# %%
sns.set_style("whitegrid")

fig, axes = plt.subplots(3,3, figsize=(16,12))

features = diabetes_dataset.columns[:-1]

for idx, feature in enumerate(features):

    row, col = idx//3, idx%3

    sns.kdeplot(
        data=diabetes_dataset,
        x=feature,
        hue="Outcome",
        fill=True,
        palette=["#4C72B0","#55A868"],
        ax=axes[row,col]
    )

    axes[row,col].set_title(feature, fontsize=12, fontweight="bold")

plt.suptitle(
    "Distribution des Variables selon le Diabète",
    fontsize=20,
    fontweight="bold",
    color="#1f4e79"
)

plt.tight_layout()
plt.show()

# %%
sns.set_style("whitegrid")

fig, axes = plt.subplots(3,3, figsize=(16,12))

features = diabetes_dataset.columns[:-1]

for idx, feature in enumerate(features):

    row, col = idx//3, idx%3

    sns.boxplot(
        x="Outcome",
        y=feature,
        data=diabetes_dataset,
        palette=["#4C72B0","#55A868"],
        ax=axes[row,col]
    )

    axes[row,col].set_title(feature, fontsize=12, fontweight="bold")

plt.suptitle(
    "Comparaison des Variables selon le Diabète",
    fontsize=20,
    fontweight="bold",
    color="#1f4e79"
)

plt.tight_layout()
plt.show()

# %%
sns.set_style("whitegrid")

fig, axes = plt.subplots(3,3, figsize=(16,12))

features = diabetes_dataset.columns[:-1]

for idx, feature in enumerate(features):

    row, col = idx//3, idx%3

    sns.violinplot(
        x="Outcome",
        y=feature,
        data=diabetes_dataset,
        palette=["#4C72B0","#55A868"],
        ax=axes[row,col]
    )

    axes[row,col].set_title(feature, fontsize=12, fontweight="bold")

plt.suptitle(
    "Distribution des Variables selon le Diabète",
    fontsize=20,
    fontweight="bold",
    color="#1f4e79"
)

plt.tight_layout()
plt.show()

# %%
x=diabetes_dataset.drop( columns=['Outcome'],axis=1)
y=diabetes_dataset['Outcome']
print(x)
print(y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
scaler=StandardScaler()
x=scaler.fit_transform(x)
x
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]], shape=(768, 8))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %%
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
classifier = svm.SVC(kernel='linear', probability=True)

classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %%
x_train_prediction = classifier.predict(x_train)

training_data_accuracy = accuracy_score(x_train_prediction, y_train)

print(training_data_accuracy)
# Out:
# 0.7719869706840391

# %%
x_test_prediction = classifier.predict(x_test)

test_data_accuracy = accuracy_score(x_test_prediction, y_test)

print(test_data_accuracy)
# Out:
# 0.7662337662337663

# %%
input_data = (5,166,72,19,175,25.8,0.587,51)

import numpy as np

input_data_as_numpy_array = np.asarray(input_data)

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = classifier.predict(input_data_reshaped)

print(prediction)
# Out:
# [1]

# %%
if prediction[0] == 0:
    print("The person is not diabetic")
else:
    print("The person is diabetic")
# Out:
# The person is diabetic

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, x_test_prediction)

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.show()

# %%
precision=precision_score(y_test, x_test_prediction)
recall=recall_score(y_test, x_test_prediction)
f1=f1_score(y_test, x_test_prediction)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Precision: 0.6285714285714286
# Recall: 0.4888888888888889
# F1 Score: 0.55

# %%
cm_svm=confusion_matrix(y_test, x_test_prediction)
cm_svm
# Out:
# array([[96, 13],
#        [23, 22]])

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
x_train_prediction_rf = rf_classifier.predict(x_train)

# %%
training_data_accuracy_rf = accuracy_score(x_train_prediction_rf, y_train)
print(training_data_accuracy_rf)
# Out:
# 1.0

# %%
x_test_prediction_rf = rf_classifier.predict(x_test)
test_data_accuracy_rf = accuracy_score(x_test_prediction_rf, y_test)

# %%
x_train_prediction_rf = rf_classifier.predict(x_test)
test_data_accuracy_rf = accuracy_score(x_train_prediction_rf, y_test)

# %%
print(test_data_accuracy_rf)
# Out:
# 0.7467532467532467

# %%
precision = precision_score(y_test, x_test_prediction_rf)

# %%
recall_rf= recall_score(y_test, x_test_prediction_rf)

# %%
f1_rf = f1_score(y_test, x_test_prediction_rf)

# %%
prediction_rf= rf_classifier.predict(input_data_reshaped)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score

# 1️⃣ Load your data
# X = features, y = target
# Example:
# X = df.drop('target', axis=1)
# y = df['target']

# 2️⃣ Split into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# 3️⃣ Define the Random Forest model
model_rf = RandomForestClassifier(n_estimators=100, random_state=42)

# 4️⃣ Train the model
model_rf.fit(x_train, y_train)

# 5️⃣ Make predictions
prediction_rf = model_rf.predict(x_test)

# 6️⃣ Calculate metrics
precision_rf = precision_score(y_test, prediction_rf)
recall_rf = recall_score(y_test, prediction_rf)
f1_rf = f1_score(y_test, prediction_rf)

# 7️⃣ Print metrics
print("Precision:", precision_rf)
print("Recall:", recall_rf)
print("F1 Score:", f1_rf)
# Out:
# Precision: 0.6181818181818182
# Recall: 0.6181818181818182
# F1 Score: 0.6181818181818182

# %%
print(precision_rf,recall_rf,f1_rf)
# Out:
# 0.6181818181818182 0.6181818181818182 0.6181818181818182

# %%
cm_rf=confusion_matrix(y_test, x_test_prediction_rf)
print(cm_rf)
# Out:
# [[91 18]
#  [21 24]]

# %%
plt.figure(figsize=(10,8))
sns.heatmap(cm_rf, annot=True, fmt='d'
            , cmap='Blues',square=True, linewidths=0.5,
            xticklabels=['Non-Diabétique', 'Diabétique'],
            yticklabels=['Non-Diabétique', 'Diabétique'])
plt.title('Matrice de Confusion - Random Forest', fontsize=16, fontweight='bold', color="#1b244b"  )
plt.show()

# %%
print('svm',test_data_accuracy)
print('Random Forest',test_data_accuracy_rf)
# Out:
# svm 0.7662337662337663
# Random Forest 0.7467532467532467

# %%
joblib.dump(rf_classifier, 'diabetes_rf_model.pkl')
# Out:
# ['diabetes_rf_model.pkl']

# %%
input_data=(5,166,72,19,175,25.8,0.587,51)
input_num_array=np.asarray(input_data)
reshape=input_num_array.reshape(1,-1)
std_data=scaler.transform(reshape)
prediction_rf=rf_classifier.predict(std_data)
prediction_rf
# Out:
# array([1])
